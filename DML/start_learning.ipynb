# %%
#driveのマウント

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install pretrainedmodels

import pretrainedmodels.utils

# !pip install -q faiss-gpu==1.6.1

# %%
#カラー学習実行
# %cd "/content/drive/My Drive/Deep-Metric-Learning-Baselines"

# !python Standard_Training_Color.py --lr 0.00001 --beta_lr 0.0005 --dataset "in-shop" --loss "triplet" --sampling "semihard" --arch "resnet50" --embed_dim 128 --n_epochs 60 --not_pretrained
# Out:
# /content/drive/My Drive/Deep-Metric-Learning-Baselines
# Not utilizing pretrained weights!
# TRIPLET Setup for RESNET50 with SEMIHARD sampling on IN-SHOP complete with #weights: 23770304
#
# -----
#
# Running with learning rates 1e-05...
# Epoch (Train) 0: Mean Loss [0.1010]: 100% 231/231 [02:57<00:00,  1.30it/s]
# Extraction Query Features: 100% 127/127 [00:31<00:00,  4.04it/s]
# Extraction Gallery Features:  37% 42/113 [00:11<00:19,  3.66it/s]Traceback (most recent call last):
#   File "Standard_Training.py", line 306, in <module>
#     eval.evaluate(opt.dataset, LOG, save=True, **eval_params)
#   File "/content/drive/My Drive/Deep-Metric-Learning-Baselines/evaluate.py", line 59, in evaluate
#     ret = evaluate_query_and_gallery_dataset(LOG, **kwargs)
#   File "/content/drive/My Drive/Deep-Metric-Learning-Baselines/evaluate.py", line 325, in evaluate_query_and_gallery_dataset
# ...

# %%
#スタイル学習実行
# %cd "/content/drive/My Drive/Deep-Metric-Learning-Baselines"

# !python Standard_Training_Style.py --lr 0.00001 --beta_lr 0.0005 --dataset "in-shop" --loss "triplet" --sampling "semihard" --arch "resnet50" --embed_dim 128 --n_epochs 60 --not_pretrained
